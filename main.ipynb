# %%
import sys
import pandas as pd
import datetime as dt
from modules import geoglows_analyzer

# Enviromental variables
forecast_path = "geoglows_forecasts"
historical_path = "geoglows_historical"
drainage_path = "geoglows_reachs_ids.xlsx"

# Define date
date = dt.datetime(2014, 1, 1)


# geoglows analyzer
ga = geoglows_analyzer(
        forecast_path=forecast_path, 
        historical_path=historical_path, 
        drainage_path=drainage_path)


a = ga.warnings(date)
a
# Out:
# Warning analysis for date: 2014-01-01
# Progress: 95.455 %. Comid: 9020518. Alert: R0
# Finished analysis...
#       comid  latitude  longitude alert
# 0   9019828   1.24480  -78.88538    R0
# 1   9019864   1.33217  -78.69150    R0
# 2   9019981   1.23703  -78.53488    R0
# 3   9019982   1.18486  -78.49713    R0
# 4   9020005   1.19144  -78.72321    R0
# 5   9020015   1.17529  -78.72930    R0
# 6   9020032   1.19530  -78.92034    R0
# 7   9020123   1.16651  -78.67721    R0
# 8   9020126   1.17439  -78.44604    R0
# 9   9020173   1.15985  -78.75776    R0
# 10  9020258   1.13515  -78.68966    R0
# 11  9020260   1.15250  -78.96077    R0
# 12  9020312   1.10186  -78.72934    R0
# 13  9020319   1.07620  -78.89440    R0
# 14  9020332   1.07723  -78.94368    R0
# 15  9020344   1.07278  -79.21623    R0
# 16  9020357   1.09378  -78.80316    R0
# 17  9020411   1.05780  -78.86678    R0
# 18  9020412   1.05087  -78.82326    R0
# 19  9020496   1.03151  -78.82985    R0
# 20  9020508   1.04364  -79.26558    R0
# 21  9020518   1.07764  -78.46847    R0
